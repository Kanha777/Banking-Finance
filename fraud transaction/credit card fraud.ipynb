# %%
import pandas as pd
import os
import pycaret
import numpy as np

# %%
os.chdir(r'C:\Users\User\Desktop\data science project\finance\fraud transaction')

# %%
df=pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]>

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
from pycaret.classification import *
model1 = setup(data = df, target = 'Class', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_2329c68a_b242_11ea_9962_5c93a2a3386e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow3_col1" class="data row3 col1" >(284807, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow5_col1" class="data row5 col1" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow10_col1" class="data row10 col1" >(213605, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow11_col1" class="data row11 col1" >(149523, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow12_col1" class="data row12 col1" >(64082, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2329c68a_b242_11ea_9962_5c93a2a3386elevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_2329c68a_b242_11ea_9962_5c93a2a3386erow18_col1" class="data row18 col1" >None</td>
#             </tr>

# %% [markdown]
# compare_models()

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=170)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               21:47:59
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Model
# ETC        . . . . . . . . . . . . . . . . . .  0.0 Seconds Remaining
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0         Random Forest Classifier    0.9995  0.9262  0.7562  0.9283  0.8322
# 1             Ada Boost Classifier    0.9992  0.9822  0.6977  0.8301  0.7554
# 2         Decision Tree Classifier    0.9991  0.8739  0.7483  0.7154  0.7306
# 3              Logistic Regression    0.9990  0.9330  0.7058  0.7055  0.7012
# 4                 Ridge Classifier    0.9989  0.0000  0.4380  0.8682  0.5792
# 5           K Neighbors Classifier    0.9984  0.6053  0.0620  0.9267  0.1139
# 6              SVM - Linear Kernel    0.9982  0.0000  0.0000  0.0000  0.0000
# 7                      Naive Bayes    0.9932  0.9689  0.6283  0.1504  0.2419
# 8  Quadratic Discriminant Analysis    0.9773  0.9691  0.8645  0.0624  0.1164
#
#     Kappa
# 0  0.8319
# 1  0.7550
# 2  0.7301
# 3  0.7007
# 4  0.5787
# 5  0.1137
# 6 -0.0001
# 7  0.2398
# 8  0.1135
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-9ff5ccfe3077> in <module>
# ----> 1 compare_models()
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\pycaret\classification.py in compare_models(blacklist, fold, round, sort, turbo)
#    3434             if hasattr(model, 'predict_proba'):
#    3435
# -> 3436                 model.fit(Xtrain,ytrain)
#    3437                 pred_prob = model.predict_proba(Xtest)
#    3438                 pred_prob = pred_prob[:,1]
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#    1535         n_stages = self._fit_stages(
#    1536             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
# -> 1537             sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1538
#    1539         # change shape of arrays after fit (early-stopping or additional ests)
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1592             raw_predictions = self._fit_stage(
#    1593                 i, X, y, raw_predictions, sample_weight, sample_mask,
# -> 1594                 random_state, X_idx_sorted, X_csc, X_csr)
#    1595
#    1596             # track deviance (= loss)
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#    1243             X = X_csr if X_csr is not None else X
#    1244             tree.fit(X, residual, sample_weight=sample_weight,
# -> 1245                      check_input=False, X_idx_sorted=X_idx_sorted)
#    1246
#    1247             # update tree leaves
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1224             sample_weight=sample_weight,
#    1225             check_input=check_input,
# -> 1226             X_idx_sorted=X_idx_sorted)
#    1227         return self
#    1228
#
# ~\Miniconda3\envs\tensorflow\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
rf=create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9993  0.8841  0.6538  0.8947  0.7556  0.7552
# 1       0.9996  0.9228  0.8077  0.9545  0.8750  0.8748
# 2       0.9995  0.9227  0.7308  0.9500  0.8261  0.8258
# 3       0.9997  0.9596  0.8400  0.9545  0.8936  0.8935
# 4       0.9994  0.9397  0.7600  0.8636  0.8085  0.8082
# 5       0.9995  0.9228  0.7692  0.9524  0.8511  0.8508
# 6       0.9995  0.9034  0.7308  0.9500  0.8261  0.8258
# 7       0.9993  0.9227  0.6923  0.8571  0.7660  0.7656
# 8       0.9997  0.9805  0.8846  0.9583  0.9200  0.9199
# 9       0.9994  0.9034  0.6923  0.9474  0.8000  0.7997
# Mean    0.9995  0.9262  0.7562  0.9283  0.8322  0.8319
# SD      0.0001  0.0267  0.0680  0.0381  0.0506  0.0507

# %%
plot_model(rf,plot = 'auc')

# %%
plot_model(rf, plot='feature')

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
predict_model(rf)
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.     F1   Kappa
# 0  Random Forest Classifier    0.9996  0.9366  0.8108  0.9574  0.878  0.8779
#            Time        V1        V2        V3        V4        V5        V6  \
# 0      155890.0  1.992524  0.608498 -1.049013  3.552099  1.001596  0.516604
# 1       70878.0  1.274456  0.065354  0.155455  0.325946 -0.157901 -0.231894
# 2        2226.0 -1.093462 -0.022031  1.698054 -2.015554  1.329095 -0.677083
# 3       80430.0 -0.929700  0.194664  1.549227  1.693430  1.038639 -0.214545
# 4      166599.0  0.080140  0.788366 -0.017010 -0.749485  0.718815 -0.651127
# ...         ...       ...       ...       ...       ...       ...       ...
# 64077  121615.0  2.038009 -1.773266 -0.935876 -1.365433 -1.546141 -0.871018
# 64078   77772.0  0.747878 -1.510703 -0.162360 -0.321021 -1.123253 -0.309674
# 64079  142424.0 -0.551508  0.882186  1.053603  1.172868 -0.358726  0.295867
# 64080  126050.0  2.060478 -0.025045 -1.085297  0.387276 -0.036530 -1.078249
# 64081  128985.0  2.333660 -1.473441 -1.461219 -1.875273 -0.729674 -0.012061
#
#              V7        V8        V9  ...       V23       V24       V25  \
# 0      0.248142 -0.022924 -0.894137  ...  0.270864 -0.038910 -0.072826
# 1     -0.163749  0.082417  0.076490  ...  0.040438 -0.544628  0.245269
# 2      0.540751 -0.136682  0.151200  ... -0.341789 -0.986180  0.436218
# 3     -0.032843  0.248009 -0.598265  ...  0.263542 -0.060427 -1.227930
# 4      0.949614 -0.103247  0.092761  ...  0.002660 -0.738013 -0.430399
# ...         ...       ...       ...  ...       ...       ...       ...
# 64077 -0.933087 -0.268409 -1.135942  ...  0.150109 -0.107236 -0.300498
# 64078 -0.074269 -0.051348 -0.980742  ... -0.206700  0.262519  0.168595
# 64079  0.128589  0.674703 -0.129583  ...  0.276702 -0.078119 -0.863724
# 64080  0.198311 -0.330286  0.475967  ...  0.333560 -0.071361 -0.288301
# 64081 -1.149132 -0.041044 -1.289589  ...  0.048349 -1.422561 -0.044577
#
#             V26       V27       V28  Amount  Class  Label  Score
# 0     -0.288485 -0.040605 -0.045592    1.91      0      0    0.0
# 1      0.133590 -0.044082 -0.002868    1.79      0      0    0.0
# 2      0.720502 -0.273701 -0.184339    3.81      0      0    0.0
# 3     -0.634669  0.062523  0.343741    0.00      0      0    0.0
# 4      0.188775  0.244657  0.088636    5.49      0      0    0.0
# ...         ...       ...       ...     ...    ...    ...    ...
# 64077 -0.207001 -0.007153 -0.027503  143.99      0      0    0.0
# 64078  1.063855 -0.115785  0.034747  294.95      0      0    0.0
# 64079 -1.024001  0.125206  0.140620   38.10      0      0    0.0
# 64080  0.204001 -0.064503 -0.060390    0.89      0      0    0.0
# 64081 -0.094088 -0.003423 -0.075217   25.00      0      0    0.0
#
# [64082 rows x 33 columns]

# %%
save_model(rf,'creditcard_fraud')
# Out:
# Transformation Pipeline and Model Succesfully Saved
